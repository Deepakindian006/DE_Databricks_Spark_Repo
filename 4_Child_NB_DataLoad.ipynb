# %%
# %py
import requests
var_data=requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
#print(var_data.text)
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",var_data.text,overwrite=True)
