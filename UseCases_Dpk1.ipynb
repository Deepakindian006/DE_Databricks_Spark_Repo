# %% [markdown]
# # <span style="color:blue">**MY FIRST LEARNING IN DATA BRICKS NOTEBOOK**</span>
# - This cell belongs to create some sample header and insert some image <br>
# ![](/Workspace/Users/deepakindian.006@gmail.com/DataBricks_Workout_2025_Dpk/DE_Image.jpeg)

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
# %run
"/Workspace/Users/deepakindian.006@gmail.com/DataBricks_Workout_2025_Dpk/1_UsesCases_NB_Fundamentals/4_Child_NB_DataLoad"

# %%
# %fs
head "dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header=True)
display(df1)

# %%
df1 = df1.withColumnRenamed(
    "Mobile Operating System",
    "Mobile_Operating_System"
).withColumnRenamed(
    "Percent of Usage",
    "Percent_of_Usage"
)
df1.write.saveAsTable("mobile_os_usage")

# %%
# %python
df1=spark.read.table("mobile_os_usage")
display(df1)

# %%
# %python
var_inp = input("Enter Name")
print(var_inp.upper())

# %%
# %pip install pandas

# %%
# %python
import pandas as pd
df1=pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df1)

# %%
# %sh
echo "Magic commands Usecases completed"
